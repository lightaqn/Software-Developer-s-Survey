# %% [markdown]
# <!-- Import necessary dependencies(Panel Data) and Stack Overflow datasets -->

# %%
import pandas as pd

# %%
na_vals = ['NA','-']
df = pd.read_csv('survey_results_public.csv', na_values=na_vals)

# %% [markdown]
# <!--  Behold the DataFrame and Question Schema containing all the datapoints we will be working with & Some basic operations-->

# %% [markdown]
# <!-- Import necessary dependencies(Panel Data) and Stack Overflow datasets -->

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 10945       10946             I am a student who is learning to code
# 26955       26956                     I am a developer by profession
# 37431       37432             I am a student who is learning to code
# 38693       38694                                      None of these
# 39471       39472                        I code primarily as a hobby
# ...           ...                                                ...
# 61695       61696                     I am a developer by profession
# 63625       63626                     I am a developer by profession
# 71573       71574  I am not primarily a developer, but I write co...
# 73741       73742                     I am a developer by profession
# 80996       80997                        I code primarily as a hobby
#
#                                               Employment      Country  \
# ...

# %%
df.shape
# Out:
# (83439, 48)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
df.tail(10)
# Out:
#        ResponseId                      MainBranch  \
# 83429       83430     I code primarily as a hobby
# 83430       83431  I am a developer by profession
# 83431       83432  I am a developer by profession
# 83432       83433  I am a developer by profession
# 83433       83434  I am a developer by profession
# 83434       83435  I am a developer by profession
# 83435       83436  I am a developer by profession
# 83436       83437  I am a developer by profession
# 83437       83438  I am a developer by profession
# 83438       83439  I am a developer by profession
#
#                                               Employment  \
# 83429                 Not employed, but looking for work
# 83430                                 Employed full-time
# 83431  Independent contractor, freelancer, or self-em...
# 83432                                 Employed full-time
# 83433  Independent contractor, freelancer, or self-em...
# 83434                                 Employed full-time
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df['ToolsTechHaveWorkedWith']
# Out:
# 0                                 NaN
# 1                     Docker;Git;Yarn
# 2                                 NaN
# 3                                 NaN
# 4          Docker;Git;Kubernetes;Yarn
#                      ...
# 83434                      Docker;Git
# 83435      Git;Unity 3D;Unreal Engine
# 83436    Ansible;Docker;Git;Terraform
# 83437    Ansible;Docker;Git;Terraform
# 83438                      Docker;Git
# Name: ToolsTechHaveWorkedWith, Length: 83439, dtype: object

# %% [markdown]
# <!--  Performing Queries accross the rows and columns -->

# %%
df.loc[0]
# Out:
# ResponseId                                                                      1
# MainBranch                                         I am a developer by profession
# Employment                      Independent contractor, freelancer, or self-em...
# Country                                                                  Slovakia
# US_State                                                                      NaN
# UK_Country                                                                    NaN
# EdLevel                         Secondary school (e.g. American high school, G...
# Age1stCode                                                          18 - 24 years
# LearnCode                       Coding Bootcamp;Other online resources (ex: vi...
# YearsCode                                                                     NaN
# YearsCodePro                                                                  NaN
# ...

# %%
df.loc[0, 'NEWCollabToolsWantToWorkWith']
# Out:
# 'Atom;Xcode'

# %%
df.loc[0:10,'ResponseId':'CompFreq']
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                     I am a developer by profession
# 1            2             I am a student who is learning to code
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# 5            6             I am a student who is learning to code
# 6            7                        I code primarily as a hobby
# 7            8             I am a student who is learning to code
# 8            9                     I am a developer by profession
# 9           10                     I am a developer by profession
# 10          11                     I am a developer by profession
#
#                                            Employment  \
# 0   Independent contractor, freelancer, or self-em...
# 1                                  Student, full-time
# ...

# %%
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6             I am a student who is learning to code
# 6           7                        I code primarily as a hobby
# 7           8             I am a student who is learning to code
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# ...

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
schema_df.sort_index(inplace=False)
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
schema_df.loc[0:9,'qid':'type']
# Out:
#       qid       qname                                           question  \
# 0   QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12    MetaInfo                                  Browser Meta Info
# 2    QID1          S1  <span style="font-size:22px; font-family: aria...
# 3    QID2  MainBranch  Which of the following options best describes ...
# 4   QID24  Employment  Which of the following best describes your cur...
# 5    QID6     Country  Where do you live? <span style="font-weight: b...
# 6    QID7    US_State  <p>In which state or territory of the USA do y...
# 7    QID9  UK_Country  In which part of the United Kingdom do you liv...
# 8  QID190          S2  <span style="font-size:22px; font-family: aria...
# 9   QID25     EdLevel  Which of the following best describes the high...
#
#    force_resp  type
# 0       False    DB
# 1       False  Meta
# 2       False    DB
# 3        True    MC
# 4       False    MC
# 5        True    MC
# ...

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %% [markdown]
# <!--  Querying for The Optimal Combination of Location and Software experience with an income above a median of 85000USD per annum -->

# %%
high_salary = (df['ConvertedCompYearly'] > 85000)

# %%
df.loc[high_salary, ['Country', 'LanguageHaveWorkedWith', 'DatabaseHaveWorkedWith','PlatformHaveWorkedWith', 'MiscTechHaveWorkedWith', 'WebframeHaveWorkedWith', 'NEWCollabToolsHaveWorkedWith']]
# Out:
#                         Country  \
# 18                    Singapore
# 31                       Israel
# 36     United States of America
# 37     United States of America
# 62     United States of America
# ...                         ...
# 83427  United States of America
# 83430  United States of America
# 83434  United States of America
# 83436  United States of America
# 83437                    Canada
#
#                                   LanguageHaveWorkedWith  \
# 18                                            C++;Python
# 31           Bash/Shell;Go;Java;Node.js;Python;Scala;SQL
# 36                           Assembly;C;Java;Kotlin;Rust
# 37                                                    Go
# 62     C#;HTML/CSS;JavaScript;Node.js;PowerShell;Pyth...
# ...                                                  ...
# 83427                                        Java;Python
# 83430        APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# ...

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt,'LanguageHaveWorkedWith']
# Out:
# 1                                        JavaScript;Python
# 2                                 Assembly;C;Python;R;Rust
# 4                           Bash/Shell;HTML/CSS;Python;SQL
# 5        C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 9                                               C++;Python
#                                ...
# 83429               HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83430          APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83431    C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83436                                   Groovy;Java;Python
# 83437                 Bash/Shell;JavaScript;Node.js;Python
# Name: LanguageHaveWorkedWith, Length: 39792, dtype: object

# %%
filt
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 83434    False
# 83435    False
# 83436     True
# 83437     True
# 83438    False
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: bool

# %%
df.loc[filt]
# Out:
#        ResponseId                                         MainBranch  \
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 4               5                     I am a developer by profession
# 5               6             I am a student who is learning to code
# 9              10                     I am a developer by profession
# ...           ...                                                ...
# 83429       83430                        I code primarily as a hobby
# 83430       83431                     I am a developer by profession
# 83431       83432                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
#
#                                               Employment  \
# 1                                     Student, full-time
# ...

# %%
df.head(40)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                     I am a developer by profession
# 1            2             I am a student who is learning to code
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# 5            6             I am a student who is learning to code
# 6            7                        I code primarily as a hobby
# 7            8             I am a student who is learning to code
# 8            9                     I am a developer by profession
# 9           10                     I am a developer by profession
# 10          11                     I am a developer by profession
# 11          12                     I am a developer by profession
# 12          13                     I am a developer by profession
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.ConvertedCompYearly
# Out:
# 0         62268.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 83434    160500.0
# 83435      3960.0
# 83436     90000.0
# 83437    816816.0
# 83438     21168.0
# Name: ConvertedCompYearly, Length: 83439, dtype: float64

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
def update_MainBranch(MainBranch):
    return MainBranch.upper()

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.apply(len, axis='columns')
# Out:
# 0        48
# 1        48
# 2        48
# 3        48
# 4        48
#          ..
# 83434    48
# 83435    48
# 83436    48
# 83437    48
# 83438    48
# Length: 83439, dtype: int64

# %%
len(df['SOPartFreq'])
# Out:
# 83439

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('JavaScript', na=False)

# %%
df.loc[filt,'ConvertedCompYearly']
# Out:
# 0         62268.0
# 1             NaN
# 3             NaN
# 5             NaN
# 6             NaN
#            ...
# 83426         NaN
# 83431     11676.0
# 83433     18326.0
# 83437    816816.0
# 83438     21168.0
# Name: ConvertedCompYearly, Length: 53587, dtype: float64

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df.rename(columns={'ConvertedCompYearly':'SalaryUSD'}, inplace=True)

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df['SalaryUSD']
# Out:
# 0         62268.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 83434    160500.0
# 83435      3960.0
# 83436     90000.0
# 83437    816816.0
# 83438     21168.0
# Name: SalaryUSD, Length: 83439, dtype: float64

# %%
df['SOAccount']
# Out:
# 0        Yes
# 1        Yes
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 83434     No
# 83435    Yes
# 83436    Yes
# 83437    Yes
# 83438    Yes
# Name: SOAccount, Length: 83439, dtype: object

# %%
df['SOAccount'].map({'Yes': True, 'No': False})
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 83434    False
# 83435     True
# 83436     True
# 83437     True
# 83438     True
# Name: SOAccount, Length: 83439, dtype: object

# %%
df['SOAccount'] = df['SOAccount'].map({'Yes': True, 'No': False})

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.sort_values(by='SalaryUSD',ascending=False)
# Out:
#        ResponseId                              MainBranch  \
# 66910       66911          I am a developer by profession
# 65399       65400          I am a developer by profession
# 40586       40587          I am a developer by profession
# 28791       28792          I am a developer by profession
# 12700       12701          I am a developer by profession
# ...           ...                                     ...
# 83414       83415             I code primarily as a hobby
# 83417       83418          I am a developer by profession
# 83418       83419  I am a student who is learning to code
# 83426       83427          I am a developer by profession
# 83429       83430             I code primarily as a hobby
#
#                                Employment                   Country  \
# 66910                 I prefer not to say                   Belgium
# 65399                  Employed full-time               Afghanistan
# ...

# %%
df.head(100)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                     I am a developer by profession
# 1            2             I am a student who is learning to code
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# ..         ...                                                ...
# 95          96                     I am a developer by profession
# 96          97                     I am a developer by profession
# 97          98                     I am a developer by profession
# 98          99                     I am a developer by profession
# 99         100                     I am a developer by profession
#
#                                            Employment  \
# 0   Independent contractor, freelancer, or self-em...
# 1                                  Student, full-time
# ...

# %% [markdown]
# <!--  Filtering for Specific Countries and their corresponding Income  -->

# %%
filt = df['Country'].str.contains('Canada', na=False)

# %%
df.loc[filt,['Country','SalaryUSD']]
# Out:
#       Country  SalaryUSD
# 17     Canada    46135.0
# 67     Canada    71850.0
# 77     Canada   151263.0
# 86     Canada    95295.0
# 89     Canada        NaN
# ...       ...        ...
# 83282  Canada    63530.0
# 83385  Canada    63530.0
# 83387  Canada   189078.0
# 83432  Canada    80169.0
# 83437  Canada   816816.0
#
# [3012 rows x 2 columns]

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.sort_values(by='Country')
# Out:
#        ResponseId                                         MainBranch  \
# 37431       37432             I am a student who is learning to code
# 11461       11462                     I am a developer by profession
# 67130       67131                     I am a developer by profession
# 62970       62971  I am not primarily a developer, but I write co...
# 14882       14883                     I am a developer by profession
# ...           ...                                                ...
# 13194       13195                     I am a developer by profession
# 80996       80997                        I code primarily as a hobby
# 73741       73742                     I am a developer by profession
# 73192       73193                     I am a developer by profession
# 38428       38429                     I am a developer by profession
#
#                                    Employment      Country US_State  \
# 37431                      Student, part-time  Afghanistan      NaN
# ...

# %% [raw]
# <!--  Sorting for Developers in each Countries and what age they took up coding -->

# %%
df.sort_values(by=['Country','Age1stCode'], ascending=[True, False], inplace=True)

# %%
df[['Country','Age1stCode']].head(50)
# Out:
#            Country            Age1stCode
# 10945  Afghanistan  Younger than 5 years
# 26955  Afghanistan  Younger than 5 years
# 37431  Afghanistan  Younger than 5 years
# 38693  Afghanistan  Younger than 5 years
# 39471  Afghanistan  Younger than 5 years
# 51791  Afghanistan  Younger than 5 years
# 55150  Afghanistan  Younger than 5 years
# 62112  Afghanistan  Younger than 5 years
# 65205  Afghanistan  Younger than 5 years
# 67508  Afghanistan  Younger than 5 years
# 68426  Afghanistan  Younger than 5 years
# 72595  Afghanistan  Younger than 5 years
# 78757  Afghanistan  Younger than 5 years
# 40223  Afghanistan   Older than 64 years
# 72314  Afghanistan   Older than 64 years
# 77979  Afghanistan   Older than 64 years
# 27198  Afghanistan          5 - 10 years
# 31504  Afghanistan          5 - 10 years
# 37549  Afghanistan          5 - 10 years
# 55624  Afghanistan          5 - 10 years
# 71691  Afghanistan          5 - 10 years
# 72965  Afghanistan          5 - 10 years
# ...

# %% [markdown]
# <!--  Querying for the top, median and smallest Salary -->

# %%
df['SalaryUSD'].nlargest(50)
# Out:
# 66910    45241312.0
# 65399    30468516.0
# 40586    21822250.0
# 28791    20000000.0
# 12700    19200000.0
# 9608     17500000.0
# 5305     15000000.0
# 12903    14411628.0
# 66488    12750000.0
# 7205     12500000.0
# 47563    12500000.0
# 3733     11250000.0
# 33255    11250000.0
# 35779    11000000.0
# 7904     10500000.0
# 10372    10350000.0
# 9189     10200000.0
# 52070    10000000.0
# 53028    10000000.0
# 66323    10000000.0
# 20908    10000000.0
# 64111    10000000.0
# 82156     9975060.0
# 7134      9500000.0
# 60701     9500000.0
# 66417     9100000.0
# 64281     9000000.0
# 51240     8850000.0
# 33313     8625145.0
# 47536     8500000.0
# 51010     8250000.0
# 47210     8100000.0
# 45288     8078700.0
# 66013     8000000.0
# 55534     8000000.0
# 33919     8000000.0
# 77060     8000000.0
# 78554     7903704.0
# 4395      7900000.0
# 54701     7900000.0
# 25102     7563129.0
# 77655     7500000.0
# 1931      7500000.0
# 5000      7500000.0
# 59563     7500000.0
# ...

# %%
df.nlargest(50,'SalaryUSD')
# Out:
#        ResponseId                                         MainBranch  \
# 66910       66911                     I am a developer by profession
# 65399       65400                     I am a developer by profession
# 40586       40587                     I am a developer by profession
# 28791       28792                     I am a developer by profession
# 12700       12701                     I am a developer by profession
# 9608         9609  I am not primarily a developer, but I write co...
# 5305         5306                     I am a developer by profession
# 12903       12904                     I am a developer by profession
# 66488       66489                     I am a developer by profession
# 7205         7206                     I am a developer by profession
# 47563       47564                     I am a developer by profession
# 3733         3734                     I am a developer by profession
# 33255       33256                     I am a developer by profession
# ...

# %%
df.nsmallest(50,'SalaryUSD')
# Out:
#        ResponseId                                         MainBranch  \
# 1924         1925                     I am a developer by profession
# 24285       24286                     I am a developer by profession
# 46464       46465  I am not primarily a developer, but I write co...
# 15163       15164                     I am a developer by profession
# 56790       56791                     I am a developer by profession
# 22032       22033                     I am a developer by profession
# 59043       59044                     I am a developer by profession
# 22453       22454                     I am a developer by profession
# 45141       45142  I am not primarily a developer, but I write co...
# 53306       53307                     I am a developer by profession
# 41440       41441                     I am a developer by profession
# 37761       37762                     I am a developer by profession
# 22162       22163                     I am a developer by profession
# ...

# %%
df['SalaryUSD'].median()
# Out:
# 56211.0

# %%
df.median()
# Out:
# ResponseId    41720.0
# CompTotal     67000.0
# SOAccount         1.0
# SalaryUSD     56211.0
# dtype: float64

# %%
df.describe()
# Out:
#          ResponseId     CompTotal     SalaryUSD
# count  83439.000000  4.718300e+04  4.684400e+04
# mean   41720.000000  2.119407e+69  1.184262e+05
# std    24086.908893  4.603702e+71  5.272944e+05
# min        1.000000  0.000000e+00  1.000000e+00
# 25%    20860.500000  1.600000e+04  2.702500e+04
# 50%    41720.000000  6.700000e+04  5.621100e+04
# 75%    62579.500000  1.400000e+05  1.000000e+05
# max    83439.000000  1.000000e+74  4.524131e+07

# %%
df['SalaryUSD'].count()
# Out:
# 46844

# %%
df['SalaryUSD'].describe()
# Out:
# count    4.684400e+04
# mean     1.184262e+05
# std      5.272944e+05
# min      1.000000e+00
# 25%      2.702500e+04
# 50%      5.621100e+04
# 75%      1.000000e+05
# max      4.524131e+07
# Name: SalaryUSD, dtype: float64

# %%
df['MainBranch']
# Out:
# 10945               I am a student who is learning to code
# 26955                       I am a developer by profession
# 37431               I am a student who is learning to code
# 38693                                        None of these
# 39471                          I code primarily as a hobby
#                                ...
# 61695                       I am a developer by profession
# 63625                       I am a developer by profession
# 71573    I am not primarily a developer, but I write co...
# 73741                       I am a developer by profession
# 80996                          I code primarily as a hobby
# Name: MainBranch, Length: 83439, dtype: object

# %%
df['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   58153
# I am a student who is learning to code                                           12029
# I am not primarily a developer, but I write code sometimes as part of my work     6578
# I code primarily as a hobby                                                       4929
# I used to be a developer by profession, but no longer am                          1237
# None of these                                                                      513
# Name: MainBranch, dtype: int64

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'SalaryUSD'],
#       dtype='object')

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %% [markdown]
# <!--  Percentage of Coding experience accross board -->

# %%
df['YearsCodePro'].value_counts(normalize=True)
# Out:
# 3                     0.094942
# 2                     0.089388
# 5                     0.083230
# 4                     0.078460
# 6                     0.062141
# 10                    0.061749
# 7                     0.051604
# 1                     0.049775
# 8                     0.046458
# Less than 1 year      0.044090
# 15                    0.036739
# 20                    0.029976
# 9                     0.029633
# 12                    0.028310
# 11                    0.025042
# 13                    0.020697
# 14                    0.017838
# 16                    0.015846
# 25                    0.014816
# 17                    0.012578
# 21                    0.012497
# 18                    0.011353
# 22                    0.010667
# 30                    0.008609
# 23                    0.008576
# 24                    0.007106
# 19                    0.006404
# 26                    0.005244
# 35                    0.004182
# 27                    0.003855
# ...

# %% [markdown]
# <!-- Querying for developer experience, population, salary per country  -->

# %%
df['Country'].value_counts().head(30)
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
# France                                                   2708
# Brazil                                                   2254
# Poland                                                   1805
# Netherlands                                              1772
# Italy                                                    1666
# Australia                                                1646
# Spain                                                    1485
# Russian Federation                                       1474
# Sweden                                                   1196
# China                                                    1055
# ...

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('Czech Republic').head(50)
# Out:
#        ResponseId                                         MainBranch  \
# 5657         5658                     I am a developer by profession
# 14435       14436                     I am a developer by profession
# 59282       59283                     I am a developer by profession
# 10732       10733                     I am a developer by profession
# 31314       31315                     I am a developer by profession
# 502           503                     I am a developer by profession
# 792           793                        I code primarily as a hobby
# 985           986                     I am a developer by profession
# 1807         1808                     I am a developer by profession
# 2237         2238  I am not primarily a developer, but I write co...
# 2283         2284                        I code primarily as a hobby
# 3121         3122                     I am a developer by profession
# 4217         4218                     I am a developer by profession
# ...

# %% [markdown]
# country_grp('LanguageWorkedWith').value_counts().head(50)

# %%
country_grp['Age'].value_counts().head(50)
# Out:
# Country      Age
# Afghanistan  25-34 years old        15
#              18-24 years old        14
#              Under 18 years old     13
#              Prefer not to say       6
#              35-44 years old         3
#              55-64 years old         2
#              65 years or older       2
#              45-54 years old         1
# Albania      18-24 years old        34
#              25-34 years old        20
#              35-44 years old         7
#              Under 18 years old      6
#              45-54 years old         1
#              65 years or older       1
# Algeria      25-34 years old        24
#              18-24 years old        15
#              35-44 years old         2
#              45-54 years old         2
#              55-64 years old         1
#              Under 18 years old      1
# Andorra      25-34 years old         5
#              18-24 years old         2
#              35-44 years old         1
# ...

# %%
country_grp['Employment'].value_counts().loc['Czech Republic']
# Out:
# Employment
# Employed full-time                                      406
# Independent contractor, freelancer, or self-employed    161
# Student, full-time                                      119
# Employed part-time                                       40
# Student, part-time                                       33
# Not employed, and not looking for work                   14
# Not employed, but looking for work                       10
# I prefer not to say                                       5
# Retired                                                   1
# Name: Employment, dtype: int64

# %%
country_grp['Employment'].value_counts(normalize=True).loc['Czech Republic']
# Out:
# Employment
# Employed full-time                                      0.514575
# Independent contractor, freelancer, or self-employed    0.204056
# Student, full-time                                      0.150824
# Employed part-time                                      0.050697
# Student, part-time                                      0.041825
# Not employed, and not looking for work                  0.017744
# Not employed, but looking for work                      0.012674
# I prefer not to say                                     0.006337
# Retired                                                 0.001267
# Name: Employment, dtype: float64

# %%
country_grp['SalaryUSD'].median().loc['Czech Republic']
# Out:
# 39564.0

# %%
country_grp['SalaryUSD'].median().loc['Germany']
# Out:
# 64859.0

# %%
country_grp['SalaryUSD'].median().loc['United States of America']
# Out:
# 125000.0

# %%
country_grp['SalaryUSD'].median().loc['Nigeria']
# Out:
# 10426.0

# %%
country_grp['SalaryUSD'].median().loc['France']
# Out:
# 48936.0

# %%
country_grp['SalaryUSD'].median().loc['Canada']
# Out:
# 75631.0

# %%
country_grp['SalaryUSD'].median().loc['Australia']
# Out:
# 80172.0

# %%
country_grp['SalaryUSD'].median().loc['Austria']
# Out:
# 54049.0

# %%
country_grp['SalaryUSD'].median().loc['Italy']
# Out:
# 36861.0

# %%
country_grp['SalaryUSD'].median().loc['China']
# Out:
# 34296.0

# %%
country_grp['SalaryUSD'].median().loc['France']
# Out:
# 48936.0

# %%
country_grp['SalaryUSD'].median().loc['Panama']
# Out:
# 39500.0

# %%
country_grp['SalaryUSD'].median().loc['Indonesia']
# Out:
# 7908.0

# %%
country_grp['SalaryUSD'].median().loc['New Zealand']
# Out:
# 70279.0

# %%
country_grp['SalaryUSD'].agg(['median','mean']).loc['Czech Republic']
# Out:
# median    39564.000000
# mean      46172.874172
# Name: Czech Republic, dtype: float64

# %%
country_grp['SalaryUSD'].agg(['median','mean'])
# Out:
#                                        median          mean
# Country
# Afghanistan                            9792.0  2.794748e+06
# Albania                               15900.0  4.499814e+04
# Algeria                                9875.0  1.446114e+04
# Andorra                               94045.5  8.928200e+04
# Angola                                 9750.0  2.155680e+04
# ...                                       ...           ...
# Venezuela, Bolivarian Republic of...  12000.0  2.246505e+04
# Viet Nam                              12678.0  1.995289e+04
# Yemen                                  3954.0  5.628667e+03
# Zambia                                 9816.0  1.991491e+04
# Zimbabwe                               7200.0  1.141477e+04
#
# [181 rows x 2 columns]

# %%
filt = df['Country'] == 'Germany'
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('JavaScript').sum()
# Out:
# 3389

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('JavaScript').sum())
# Out:
# Country
# Afghanistan                              32
# Albania                                  51
# Algeria                                  29
# Andorra                                   8
# Angola                                   14
#                                        ...
# Venezuela, Bolivarian Republic of...     91
# Viet Nam                                244
# Yemen                                     8
# Zambia                                   16
# Zimbabwe                                 22
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
country_respondents = df['Country'].value_counts()

# %%
country_respondents
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Liechtenstein                                               1
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Brunei Darussalam                                           1
# Saint Vincent and the Grenadines                            1
# Name: Country, Length: 181, dtype: int64

# %% [markdown]
# <!-- Sorting through the most popular programming languages and  Select Webframeworks in an indivdual or group of countries with percentages -->

# %%
country_uses_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                                                     Country  \
# United States of America                              15288
# India                                                 10511
# Germany                                                5625
# United Kingdom of Great Britain and Northern Ir...     4475
# Canada                                                 3012
# ...                                                     ...
# Liechtenstein                                             1
# Saint Kitts and Nevis                                     1
# Dominica                                                  1
# Brunei Darussalam                                         1
# Saint Vincent and the Grenadines                          1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                              7975
# India                                                                 5233
# ...

# %%
 python_df.rename(columns={'Country': 'NumRespondents', 'LanguageHaveWorkedWith':'NumKnowsPython'}, inplace=True)

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents'])*100
python_df
# Out:
#                                                     NumRespondents  \
# United States of America                                     15288
# India                                                        10511
# Germany                                                       5625
# United Kingdom of Great Britain and Northern Ir...            4475
# Canada                                                        3012
# ...                                                            ...
# Liechtenstein                                                    1
# Saint Kitts and Nevis                                            1
# Dominica                                                         1
# Brunei Darussalam                                                1
# Saint Vincent and the Grenadines                                 1
#
#                                                     NumKnowsPython  \
# United States of America                                      7975
# ...

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.head(50)
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Dominica                                       1               1
# Liechtenstein                                  1               1
# Brunei Darussalam                              1               1
# Tuvalu                                         1               1
# Sierra Leone                                   2               2
# Burundi                                        5               4
# Burkina Faso                                   4               3
# Namibia                                       12               9
# Bahamas                                        7               5
# Qatar                                         29              20
# Liberia                                        3               2
# Saint Lucia                                    3               2
# Cuba                                          34              22
# ...

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    429.000000
# NumKnowsPython    209.000000
# PctKnowsPython     48.717949
# Name: Japan, dtype: float64

# %%
country_uses_JavaScript = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('JavaScript').sum())
country_uses_JavaScript
# Out:
# Country
# Afghanistan                              32
# Albania                                  51
# Algeria                                  29
# Andorra                                   8
# Angola                                   14
#                                        ...
# Venezuela, Bolivarian Republic of...     91
# Viet Nam                                244
# Yemen                                     8
# Zambia                                   16
# Zimbabwe                                 22
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
JavaScript_df = pd.concat([country_respondents, country_uses_JavaScript], axis='columns', sort=False)
JavaScript_df
# Out:
#                                                     Country  \
# United States of America                              15288
# India                                                 10511
# Germany                                                5625
# United Kingdom of Great Britain and Northern Ir...     4475
# Canada                                                 3012
# ...                                                     ...
# Liechtenstein                                             1
# Saint Kitts and Nevis                                     1
# Dominica                                                  1
# Brunei Darussalam                                         1
# Saint Vincent and the Grenadines                          1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                              9987
# India                                                                 6460
# ...

# %%
JavaScript_df.rename(columns={'Country': 'NumRespondents', 'LanguageHaveWorkedWith':'NumKnowsJavaScript'}, inplace=True)

# %%
JavaScript_df
# Out:
#                                                     NumRespondents  \
# United States of America                                     15288
# India                                                        10511
# Germany                                                       5625
# United Kingdom of Great Britain and Northern Ir...            4475
# Canada                                                        3012
# ...                                                            ...
# Liechtenstein                                                    1
# Saint Kitts and Nevis                                            1
# Dominica                                                         1
# Brunei Darussalam                                                1
# Saint Vincent and the Grenadines                                 1
#
#                                                     NumKnowsJavaScript
# United States of America                                          9987
# ...

# %%
JavaScript_df['PctKnowsJavaScript'] = (JavaScript_df['NumKnowsJavaScript']/JavaScript_df['NumRespondents'])*100
python_df
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Dominica                                       1               1
# Liechtenstein                                  1               1
# Brunei Darussalam                              1               1
# Tuvalu                                         1               1
# Sierra Leone                                   2               2
# ...                                          ...             ...
# Papua New Guinea                               1               0
# San Marino                                     2               0
# Lesotho                                        4               0
# Mali                                           2               0
# Saint Vincent and the Grenadines               1               0
#
#                                   PctKnowsPython
# Dominica                                   100.0
# Liechtenstein                              100.0
# ...

# %%
JavaScript_df.sort_values(by='PctKnowsJavaScript', ascending=False, inplace=True)

# %%
country_grp['WebframeHaveWorkedWith'].apply(lambda x: x.str.contains('React').sum())
# Out:
# Country
# Afghanistan                              14
# Albania                                  21
# Algeria                                   8
# Andorra                                   4
# Angola                                    8
#                                        ...
# Venezuela, Bolivarian Republic of...     45
# Viet Nam                                129
# Yemen                                     0
# Zambia                                    5
# Zimbabwe                                 16
# Name: WebframeHaveWorkedWith, Length: 181, dtype: int64

# %%
country_uses_React = country_grp['WebframeHaveWorkedWith'].apply(lambda x: x.str.contains('React').sum())
country_uses_React
# Out:
# Country
# Afghanistan                              14
# Albania                                  21
# Algeria                                   8
# Andorra                                   4
# Angola                                    8
#                                        ...
# Venezuela, Bolivarian Republic of...     45
# Viet Nam                                129
# Yemen                                     0
# Zambia                                    5
# Zimbabwe                                 16
# Name: WebframeHaveWorkedWith, Length: 181, dtype: int64

# %%
React_df = pd.concat([country_respondents, country_uses_React], axis='columns', sort=False)
React_df
# Out:
#                                                     Country  \
# United States of America                              15288
# India                                                 10511
# Germany                                                5625
# United Kingdom of Great Britain and Northern Ir...     4475
# Canada                                                 3012
# ...                                                     ...
# Liechtenstein                                             1
# Saint Kitts and Nevis                                     1
# Dominica                                                  1
# Brunei Darussalam                                         1
# Saint Vincent and the Grenadines                          1
#
#                                                     WebframeHaveWorkedWith
# United States of America                                              4804
# India                                                                 3442
# ...

# %%
 React_df.rename(columns={'Country': 'NumRespondents', 'WebframeHaveWorkedWith':'NumKnowsReact'}, inplace=True)

# %%
React_df['PctKnowsReact'] = (React_df['NumKnowsReact']/React_df['NumRespondents'])*100
React_df
# Out:
#                                                     NumRespondents  \
# United States of America                                     15288
# India                                                        10511
# Germany                                                       5625
# United Kingdom of Great Britain and Northern Ir...            4475
# Canada                                                        3012
# ...                                                            ...
# Liechtenstein                                                    1
# Saint Kitts and Nevis                                            1
# Dominica                                                         1
# Brunei Darussalam                                                1
# Saint Vincent and the Grenadines                                 1
#
#                                                     NumKnowsReact  \
# United States of America                                     4804
# ...

# %% [markdown]
# <!--  Probing through Developers Educational Level  -->

# %%
NumEduQ = df['EdLevel'].value_counts()

# %%
NumEduQ
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          35357
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       17512
# Some college/university study without earning a degree                                10589
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     9534
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             2567
# Primary/elementary school                                                              2479
# Associate degree (A.A., A.S., etc.)                                                    2231
# Something else                                                                         1601
# Professional degree (JD, MD, etc.)                                                     1256
# Name: EdLevel, dtype: int64

# %%
NumEduQ.describe().max()
# Out:
# 35357.0

# %%
Num_df = pd.concat([NumEduQ], axis='columns', sort=False)
Num_df
# Out:
#                                                     EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)          35357
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       17512
# Some college/university study without earning a...    10589
# Secondary school (e.g. American high school, Ge...     9534
# Other doctoral degree (Ph.D., Ed.D., etc.)             2567
# Primary/elementary school                              2479
# Associate degree (A.A., A.S., etc.)                    2231
# Something else                                         1601
# Professional degree (JD, MD, etc.)                     1256

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 10945       10946             I am a student who is learning to code
# 26955       26956                     I am a developer by profession
# 37431       37432             I am a student who is learning to code
# 38693       38694                                      None of these
# 39471       39472                        I code primarily as a hobby
# ...           ...                                                ...
# 61695       61696                     I am a developer by profession
# 63625       63626                     I am a developer by profession
# 71573       71574  I am not primarily a developer, but I write co...
# 73741       73742                     I am a developer by profession
# 80996       80997                        I code primarily as a hobby
#
#                                               Employment      Country  \
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [ResponseId, MainBranch, Employment, Country, US_State, UK_Country, EdLevel, Age1stCode, LearnCode, YearsCode, YearsCodePro, DevType, OrgSize, Currency, CompTotal, CompFreq, LanguageHaveWorkedWith, LanguageWantToWorkWith, DatabaseHaveWorkedWith, DatabaseWantToWorkWith, PlatformHaveWorkedWith, PlatformWantToWorkWith, WebframeHaveWorkedWith, WebframeWantToWorkWith, MiscTechHaveWorkedWith, MiscTechWantToWorkWith, ToolsTechHaveWorkedWith, ToolsTechWantToWorkWith, NEWCollabToolsHaveWorkedWith, NEWCollabToolsWantToWorkWith, OpSys, NEWStuck, NEWSOSites, SOVisitFreq, SOAccount, SOPartFreq, SOComm, NEWOtherComms, Age, Gender, Trans, Sexuality, Ethnicity, Accessibility, MentalHealth, SurveyLength, SurveyEase, SalaryUSD]
# Index: []

# %%
df.dropna(axis='index', how='any')
# Out:
# Empty DataFrame
# Columns: [ResponseId, MainBranch, Employment, Country, US_State, UK_Country, EdLevel, Age1stCode, LearnCode, YearsCode, YearsCodePro, DevType, OrgSize, Currency, CompTotal, CompFreq, LanguageHaveWorkedWith, LanguageWantToWorkWith, DatabaseHaveWorkedWith, DatabaseWantToWorkWith, PlatformHaveWorkedWith, PlatformWantToWorkWith, WebframeHaveWorkedWith, WebframeWantToWorkWith, MiscTechHaveWorkedWith, MiscTechWantToWorkWith, ToolsTechHaveWorkedWith, ToolsTechWantToWorkWith, NEWCollabToolsHaveWorkedWith, NEWCollabToolsWantToWorkWith, OpSys, NEWStuck, NEWSOSites, SOVisitFreq, SOAccount, SOPartFreq, SOComm, NEWOtherComms, Age, Gender, Trans, Sexuality, Ethnicity, Accessibility, MentalHealth, SurveyLength, SurveyEase, SalaryUSD]
# Index: []

# %%
df.dropna(axis='columns', how='all')
# Out:
#        ResponseId                                         MainBranch  \
# 10945       10946             I am a student who is learning to code
# 26955       26956                     I am a developer by profession
# 37431       37432             I am a student who is learning to code
# 38693       38694                                      None of these
# 39471       39472                        I code primarily as a hobby
# ...           ...                                                ...
# 61695       61696                     I am a developer by profession
# 63625       63626                     I am a developer by profession
# 71573       71574  I am not primarily a developer, but I write co...
# 73741       73742                     I am a developer by profession
# 80996       80997                        I code primarily as a hobby
#
#                                               Employment      Country  \
# ...

# %%
df.dropna(axis='index', how='any', subset=['CompTotal', 'Currency', 'DevType', 'SOAccount'])
# Out:
#        ResponseId                      MainBranch  \
# 27198       27199  I am a developer by profession
# 22666       22667  I am a developer by profession
# 14882       14883  I am a developer by profession
# 17120       17121  I am a developer by profession
# 17486       17487  I am a developer by profession
# ...           ...                             ...
# 54148       54149  I am a developer by profession
# 73192       73193  I am a developer by profession
# 50221       50222  I am a developer by profession
# 61695       61696  I am a developer by profession
# 63625       63626  I am a developer by profession
#
#                                               Employment      Country  \
# 27198  Independent contractor, freelancer, or self-em...  Afghanistan
# 22666  Independent contractor, freelancer, or self-em...  Afghanistan
# 14882                                 Employed full-time  Afghanistan
# 17120                                 Employed full-time  Afghanistan
# ...

# %%
import numpy as np

# %%
df.replace('NA', np.nan, inplace=True)
df.replace('Missing', np.nan, inplace=True)

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 10945       10946             I am a student who is learning to code
# 26955       26956                     I am a developer by profession
# 37431       37432             I am a student who is learning to code
# 38693       38694                                      None of these
# 39471       39472                        I code primarily as a hobby
# ...           ...                                                ...
# 61695       61696                     I am a developer by profession
# 63625       63626                     I am a developer by profession
# 71573       71574  I am not primarily a developer, but I write co...
# 73741       73742                     I am a developer by profession
# 80996       80997                        I code primarily as a hobby
#
#                                               Employment      Country  \
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [ResponseId, MainBranch, Employment, Country, US_State, UK_Country, EdLevel, Age1stCode, LearnCode, YearsCode, YearsCodePro, DevType, OrgSize, Currency, CompTotal, CompFreq, LanguageHaveWorkedWith, LanguageWantToWorkWith, DatabaseHaveWorkedWith, DatabaseWantToWorkWith, PlatformHaveWorkedWith, PlatformWantToWorkWith, WebframeHaveWorkedWith, WebframeWantToWorkWith, MiscTechHaveWorkedWith, MiscTechWantToWorkWith, ToolsTechHaveWorkedWith, ToolsTechWantToWorkWith, NEWCollabToolsHaveWorkedWith, NEWCollabToolsWantToWorkWith, OpSys, NEWStuck, NEWSOSites, SOVisitFreq, SOAccount, SOPartFreq, SOComm, NEWOtherComms, Age, Gender, Trans, Sexuality, Ethnicity, Accessibility, MentalHealth, SurveyLength, SurveyEase, SalaryUSD]
# Index: []

# %%
 df.isna()
# Out:
#        ResponseId  MainBranch  Employment  Country  US_State  UK_Country  \
# 10945       False       False       False    False      True        True
# 26955       False       False       False    False      True        True
# 37431       False       False       False    False      True        True
# 38693       False       False       False    False      True        True
# 39471       False       False       False    False      True        True
# ...           ...         ...         ...      ...       ...         ...
# 61695       False       False       False    False      True        True
# 63625       False       False       False    False      True        True
# 71573       False       False       False    False      True        True
# 73741       False       False       False    False      True        True
# 80996       False       False       False    False      True        True
#
#        EdLevel  Age1stCode  LearnCode  YearsCode  YearsCodePro  DevType  \
# ...

# %%
df.fillna('-')
# Out:
#        ResponseId                                         MainBranch  \
# 10945       10946             I am a student who is learning to code
# 26955       26956                     I am a developer by profession
# 37431       37432             I am a student who is learning to code
# 38693       38694                                      None of these
# 39471       39472                        I code primarily as a hobby
# ...           ...                                                ...
# 61695       61696                     I am a developer by profession
# 63625       63626                     I am a developer by profession
# 71573       71574  I am not primarily a developer, but I write co...
# 73741       73742                     I am a developer by profession
# 80996       80997                        I code primarily as a hobby
#
#                                               Employment      Country  \
# ...

# %%
df.dtypes
# Out:
# ResponseId                        int64
# MainBranch                       object
# Employment                       object
# Country                          object
# US_State                         object
# UK_Country                       object
# EdLevel                          object
# Age1stCode                       object
# LearnCode                        object
# YearsCode                        object
# YearsCodePro                     object
# DevType                          object
# OrgSize                          object
# Currency                         object
# CompTotal                       float64
# CompFreq                         object
# LanguageHaveWorkedWith           object
# LanguageWantToWorkWith           object
# DatabaseHaveWorkedWith           object
# DatabaseWantToWorkWith           object
# PlatformHaveWorkedWith           object
# PlatformWantToWorkWith           object
# WebframeHaveWorkedWith           object
# ...

# %%
type(np.nan)
# Out:
# float

# %%
df['CompTotal'] = df['CompTotal'].astype(float)

# %%
df.dtypes
# Out:
# ResponseId                        int64
# MainBranch                       object
# Employment                       object
# Country                          object
# US_State                         object
# UK_Country                       object
# EdLevel                          object
# Age1stCode                       object
# LearnCode                        object
# YearsCode                        object
# YearsCodePro                     object
# DevType                          object
# OrgSize                          object
# Currency                         object
# CompTotal                       float64
# CompFreq                         object
# LanguageHaveWorkedWith           object
# LanguageWantToWorkWith           object
# DatabaseHaveWorkedWith           object
# DatabaseWantToWorkWith           object
# PlatformHaveWorkedWith           object
# PlatformWantToWorkWith           object
# WebframeHaveWorkedWith           object
# ...

# %%
df['SalaryUSD'].mean()
# Out:
# 118426.15289044488

# %%
df['YearsCodePro'].unique()
# Out:
# array([nan, '6', 'More than 50 years', '26', 'Less than 1 year', '3', '5',
#        '10', '2', '4', '1', '13', '11', '15', '8', '7', '17', '20', '25',
#        '9', '14', '16', '12', '18', '23', '28', '24', '35', '19', '30',
#        '22', '21', '32', '34', '31', '44', '36', '46', '39', '33', '27',
#        '37', '29', '40', '45', '38', '50', '41', '42', '43', '49', '47',
#        '48'], dtype=object)

# %%
df['YearsCode'].unique()
# Out:
# array(['4', '7', nan, 'More than 50 years', 'Less than 1 year', '32', '2',
#        '1', '3', '9', '20', '5', '6', '10', '8', '16', '11', '23', '12',
#        '25', '13', '30', '18', '15', '46', '14', '22', '31', '27', '37',
#        '35', '36', '26', '28', '34', '21', '41', '17', '38', '40', '24',
#        '19', '33', '39', '42', '50', '43', '29', '45', '49', '47', '48',
#        '44'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].median()
# Out:
# 10.0

# %% [markdown]
# <!-- The United States is the highest paying Country with the largest percentage of JavaScript and Python developers at a median salary of 125,000 per annum.  Nigeria offers an average of 11000USD salary per annum. React.js enjoys a 31% adoption rate in the US, a number that shares a close proximity to the median.   -->
#
# <!-- The most lucrative programming language in terms of adoption rate and per diem is Python, closely followed by JavaScript, 30% of correspondents have atleast a bachelor's degree -->
